# %%
import pandas as pd

my_books = pd.read_csv("liked_books.csv", index_col = 0)

# %%
my_books
# Out:
#      user_id   book_id  rating  \
# 0         -1   2517439       5
# 1         -1    113576       5
# 2         -1     35100       5
# 3         -1    228221       5
# 5         -1  17662739       5
# 6         -1    356824       5
# 7         -1  12125412       5
# 8         -1    139069       5
# 10        -1     76680       5
# 11        -1      1898       5
# 12        -1   5096865       5
# 13        -1    228665       5
# 17        -1    437143       5
# 18        -1  18949861       5
# 19        -1   2913377       5
# 20        -1   1215032       5
# 21        -1    883438       5
# 22        -1   5578108       5
# 23        -1    128029       5
# 24        -1     77203       5
# 25        -1      5439       5
# 26        -1   1685995       5
# 27        -1   6448772       5
# 527       -1   8161140       1
# 528       -1     28187       1
# 531       -1  25659450       1
# 532       -1     82599       1
#
#                                                  title
# 0               The Forever War  (The Forever War, #1)
# 1    The Smartest Guys in the Room: The Amazing Ris...
# 2                                Battle Cry of Freedom
# 3                                  The Mask of Command
# 5           2001: A Space Odyssey  (Space Odyssey, #1)
# 6    India After Gandhi: The History of the World's...
# 7      The Lady or the Tiger?: and Other Logic Puzzles
# 8            Endurance: Shackleton's Incredible Voyage
# 10                        Foundation  (Foundation, #1)
# 11   Into Thin Air: A Personal Account of the Mount...
# 12                                       In Cold Blood
# 13       The Eye of the World  (The Wheel of Time, #1)
# 17                A Short History of Nearly Everything
# 18                                             Contact
# 19   The Name of the Wind  (The Kingkiller Chronicl...
# 20   The Wise Man's Fear  (The Kingkiller Chronicle...
# 21                                        East of Eden
# 22   From Colony to Superpower: U.S. Foreign Relati...
# 23                            A Thousand Splendid Suns
# 24                                     The Kite Runner
# 25                             Interpreter of Maladies
# 26                                     Dune  (Dune #1)
# 27   Quantum: Einstein, Bohr, and the Great Debate ...
# 527                                       On the Beach
# 528  The Lightning Thief  (Percy Jackson and the Ol...
# 531                                          Arkwright
# 532                                   Rabbits: A Novel

# %%
my_books["book_id"] = my_books["book_id"].astype(str)

# %%
csv_book_mapping = {}
with open("book_id_map.csv", "r") as f:
    while True:
        line = f.readline()
        if not line:
            break
        csv_id, book_id = line.strip().split(",")
        csv_book_mapping[csv_id] = book_id

# %%
book_set = set(my_books["book_id"])

# %%
overlap_users = {}

with open("goodreads_interactions.csv", "r") as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.strip().split(",")
        book_id = csv_book_mapping.get(csv_id)
        if book_id in book_set:
            if user_id not in overlap_users:
                overlap_users[user_id] = 1
            else:
                overlap_users[user_id] += 1

# %%
len(overlap_users)
# Out:
# 316341

# %%
filter_overlap_users = set([k for k in overlap_users if overlap_users[k] > my_books.shape[0]/10])

# %%
interactions_list = []

with open("goodreads_interactions.csv", "r") as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.strip().split(",")
        if user_id in filter_overlap_users:
            book_id = csv_book_mapping.get(csv_id)
            interactions_list.append([user_id, book_id, rating])

# %%
len(interactions_list)
# Out:
# 42786499

# %%
interactions_list[0]
# Out:
# ['0', '12', '5']

# %%
interactions = pd.DataFrame(interactions_list, columns = ["user_id", "book_id", "rating"])

# %%
interactions = pd.concat([my_books[["user_id", "book_id", "rating"]], interactions])

# %%
interactions
# Out:
#          user_id   book_id rating
# 0             -1   2517439      5
# 1             -1    113576      5
# 2             -1     35100      5
# 3             -1    228221      5
# 5             -1  17662739      5
# ...          ...       ...    ...
# 42786494  876022     94053      4
# 42786495  876022  16071764      5
# 42786496  876022  32938155      5
# 42786497  876022  25937671      0
# 42786498  876022  13547504      0
#
# [42786526 rows x 3 columns]

# %%
interactions["book_id"] = interactions["book_id"].astype(str)
interactions["user_id"] = interactions["user_id"].astype(str)
interactions["rating"] = pd.to_numeric(interactions["rating"])

# %%
interactions["user_id"].unique()
# Out:
# array(['-1', '0', '15', ..., '875781', '875835', '876022'], dtype=object)

# %%
interactions["user_index"] = interactions["user_id"].astype("category").cat.codes

# %%
interactions["book_index"] = interactions["book_id"].astype("category").cat.codes

# %%
len(interactions["book_index"].unique())
# Out:
# 1466746

# %%
from scipy.sparse import coo_matrix

ratings_mat_coo = coo_matrix((interactions["rating"], (interactions["user_index"], interactions["book_index"])))

# %%
ratings_mat_coo
# Out:
# <46465x1466746 sparse matrix of type '<class 'numpy.int64'>'
# 	with 42786526 stored elements in COOrdinate format>

# %%
ratings_mat = ratings_mat_coo.tocsr()

# %%
interactions[interactions["user_id"] == "-1"]
# Out:
#     user_id   book_id  rating  user_index  book_index
# 0        -1   2517439       5           0      757635
# 1        -1    113576       5           0       70745
# 2        -1     35100       5           0     1077282
# 3        -1    228221       5           0      648675
# 5        -1  17662739       5           0      386625
# 6        -1    356824       5           0     1090831
# 7        -1  12125412       5           0      108535
# 8        -1    139069       5           0      225316
# 10       -1     76680       5           0     1324012
# 11       -1      1898       5           0      498398
# 12       -1   5096865       5           0     1163416
# 13       -1    228665       5           0      652006
# 17       -1    437143       5           0     1134738
# 18       -1  18949861       5           0      496788
# 19       -1   2913377       5           0      912662
# 20       -1   1215032       5           0      109697
# 21       -1    883438       5           0     1403421
# 22       -1   5578108       5           0     1180826
# 23       -1    128029       5           0      141949
# 24       -1     77203       5           0     1327973
# 25       -1      5439       5           0     1175646
# 26       -1   1685995       5           0      339975
# 27       -1   6448772       5           0     1236285
# 527      -1   8161140       1           0     1359294
# 528      -1     28187       1           0      881661
# 531      -1  25659450       1           0      788367
# 532      -1     82599       1           0     1366251

# %%
my_index = 0

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity = cosine_similarity(ratings_mat[my_index,:], ratings_mat).flatten()

# %%
similarity[1]
# Out:
# 0.019866980414254484

# %%
import numpy as np

indices = np.argpartition(similarity, -30)[30:]

# %%
indices
# Out:
# array([   30,    31, 46450, ..., 39380, 30432,     0], dtype=int64)

# %%
similar_users = interactions[interactions["user_index"].isin(indices)].copy()

# %%
similar_users = similar_users[similar_users["user_id"] != "-1"]

# %%
similar_users
# Out:
#          user_id   book_id  rating  user_index  book_index
# 0              0        12       5           1      102205
# 1              0        21       5           1      573452
# 2              0        30       5           1      942427
# 3              0        45       5           1     1140017
# 4              0         1       5           1           0
# ...          ...       ...     ...         ...         ...
# 42786494  876022     94053       4       45028     1430294
# 42786495  876022  16071764       5       45028      305760
# 42786496  876022  32938155       5       45028     1021642
# 42786497  876022  25937671       0       45028      808500
# 42786498  876022  13547504       0       45028      200044
#
# [42759609 rows x 5 columns]

# %%
book_recs = similar_users.groupby("book_id").rating.agg(['count', 'mean'])

# %%
book_recs
# Out:
#          count      mean
# book_id
# 1        27475  3.917671
# 10         452  4.095133
# 100          5  1.600000
# 1000        34  0.441176
# 10000      227  0.475771
# ...        ...       ...
# 9999934      2  0.000000
# 9999954      3  2.000000
# 9999969      4  0.750000
# 999999      19  1.473684
# 9999995     21  2.095238
#
# [1466642 rows x 2 columns]

# %%
book_titles = pd.read_json("books_titles.json")
book_titles["book_id"] = book_titles["book_id"].astype(str)

# %%
book_recs = book_recs.merge(book_titles, how="inner", on="book_id")

# %%
book_recs
# Out:
#          book_id  count      mean  \
# 0              1  27475  3.917671
# 1             10    452  4.095133
# 2            100      5  1.600000
# 3           1000     34  0.441176
# 4          10000    227  0.475771
# ...          ...    ...       ...
# 1094619  9999934      2  0.000000
# 1094620  9999954      3  2.000000
# 1094621  9999969      4  0.750000
# 1094622   999999     19  1.473684
# 1094623  9999995     21  2.095238
#
#                                                      title  ratings  \
# 0        Harry Potter and the Half-Blood Prince (Harry ...  1713866
# 1             Harry Potter Collection (Harry Potter, #1-6)    25245
# 2                                 Simply Beautiful Beading       75
# 3        Millionaire Women Next Door: The Many Journeys...      460
# 4                                      The Face of Another     2079
# ...                                                    ...      ...
# 1094619                             Ten Moonstruck Piglets       61
# 1094620                                         Dijkshoorn      175
# 1094621                                  Alien Aberrations       17
# 1094622                                          Roommates       46
# 1094623                                      Cinnamon Baby      142
#
#                                                        url  \
# 0        https://www.goodreads.com/book/show/1.Harry_Po...
# 1        https://www.goodreads.com/book/show/10.Harry_P...
# 2        https://www.goodreads.com/book/show/100.Simply...
# 3        https://www.goodreads.com/book/show/1000.Milli...
# 4        https://www.goodreads.com/book/show/10000.The_...
# ...                                                    ...
# 1094619  https://www.goodreads.com/book/show/9999934-te...
# 1094620  https://www.goodreads.com/book/show/9999954-di...
# 1094621  https://www.goodreads.com/book/show/9999969-al...
# 1094622  https://www.goodreads.com/book/show/999999.Roo...
# 1094623  https://www.goodreads.com/book/show/9999995-ci...
#
#                                                cover_image  \
# 0        https://images.gr-assets.com/books/1361039191m...
# 1        https://images.gr-assets.com/books/1328867351m...
# 2        https://s.gr-assets.com/assets/nophoto/book/11...
# 3        https://s.gr-assets.com/assets/nophoto/book/11...
# 4        https://images.gr-assets.com/books/1320415026m...
# ...                                                    ...
# 1094619  https://s.gr-assets.com/assets/nophoto/book/11...
# 1094620  https://s.gr-assets.com/assets/nophoto/book/11...
# 1094621  https://images.gr-assets.com/books/1293137133m...
# 1094622  https://s.gr-assets.com/assets/nophoto/book/11...
# 1094623  https://s.gr-assets.com/assets/nophoto/book/11...
#
#                                                  mod_title
# 0        harry potter and the halfblood prince harry po...
# 1                  harry potter collection harry potter 16
# 2                                 simply beautiful beading
# 3        millionaire women next door the many journeys ...
# 4                                      the face of another
# ...                                                    ...
# 1094619                             ten moonstruck piglets
# 1094620                                         dijkshoorn
# 1094621                                  alien aberrations
# 1094622                                          roommates
# 1094623                                      cinnamon baby
#
# [1094624 rows x 8 columns]

# %%
book_recs["adjusted_count"] = book_recs["count"] * (book_recs["count"] / book_recs["ratings"])

# %%
book_recs["score"] = book_recs["mean"] * book_recs["adjusted_count"]

# %%
book_recs = book_recs[~book_recs["book_id"].isin(my_books["book_id"])]

# %%
my_books["mod_title"] = my_books["title"].str.replace("[^a-zA-Z0-9]", "", regex = True).str.lower()

# %%
my_books["mod_title"] = my_books["mod_title"].str.replace("\s+"," ", regex = True)

# %%
book_recs = book_recs[~book_recs["mod_title"].isin(my_books["mod_title"])]

# %%
book_recs = book_recs[book_recs["count"] > 10]

# %%
book_recs = book_recs[book_recs["mean"] > 4]

# %%
top_recs = book_recs.sort_values("score", ascending = False)

# %%
top_recs
# Out:
#           book_id  count      mean  \
# 847638          5  28048  4.005419
# 694489          3  34576  4.125000
# 961156      72193    776  4.051546
# 1050789     90072   1228  4.182410
# 836827     464164    596  4.068792
# ...           ...    ...       ...
# 683683    2954458     11  4.090909
# 665964   28767931     16  4.250000
# 1021193    840577     17  4.058824
# 920824    6573344     11  4.363636
# 923113    6596839     25  4.160000
#
#                                                      title  ratings  \
# 847638   Harry Potter and the Prisoner of Azkaban (Harr...  1876252
# 694489   Harry Potter and the Sorcerer's Stone (Harry P...  4765497
# 961156   Harry Potter and the Philosopher's Stone (Harr...    31614
# 1050789  Dr. Seuss's Green Eggs and Ham: For Soprano, B...    91573
# 836827   Harry Potter and the Prisoner of Azkaban (Harr...    22794
# ...                                                    ...      ...
# 683683   Harry Potter en de Halfbloed Prins (Harry Pott...     1254
# 665964   Harry Potter and the Half-Blood Prince (Harry ...     2784
# 1021193  Harry Potter und der Halbblutprinz (Harry Pott...     3353
# 920824                       Blood Work (Terry McCaleb #1)     1605
# 923113   Los juegos del hambre (Los juegos del hambre, #1)     8370
#
#                                                        url  \
# 847638   https://www.goodreads.com/book/show/5.Harry_Po...
# 694489   https://www.goodreads.com/book/show/3.Harry_Po...
# 961156   https://www.goodreads.com/book/show/72193.Harr...
# 1050789  https://www.goodreads.com/book/show/90072.Dr_S...
# 836827   https://www.goodreads.com/book/show/464164.Har...
# ...                                                    ...
# 683683   https://www.goodreads.com/book/show/2954458-ha...
# 665964   https://www.goodreads.com/book/show/28767931-h...
# 1021193  https://www.goodreads.com/book/show/840577.Har...
# 920824   https://www.goodreads.com/book/show/6573344-bl...
# 923113   https://www.goodreads.com/book/show/6596839-lo...
#
#                                                cover_image  \
# 847638   https://images.gr-assets.com/books/1499277281m...
# 694489   https://images.gr-assets.com/books/1474154022m...
# 961156   https://images.gr-assets.com/books/1327190600m...
# 1050789  https://s.gr-assets.com/assets/nophoto/book/11...
# 836827   https://images.gr-assets.com/books/1310384602m...
# ...                                                    ...
# 683683   https://images.gr-assets.com/books/1372329105m...
# 665964   https://s.gr-assets.com/assets/nophoto/book/11...
# 1021193  https://s.gr-assets.com/assets/nophoto/book/11...
# 920824   https://images.gr-assets.com/books/1328202999m...
# 923113   https://images.gr-assets.com/books/1335891621m...
#
#                                                  mod_title  adjusted_count  \
# 847638   harry potter and the prisoner of azkaban harry...      419.288189
# 694489   harry potter and the sorcerers stone harry pot...      250.865707
# 961156   harry potter and the philosophers stone harry ...       19.047764
# 1050789  dr seusss green eggs and ham for soprano boy s...       16.467561
# 836827   harry potter and the prisoner of azkaban harry...       15.583750
# ...                                                    ...             ...
# 683683   harry potter en de halfbloed prins harry potter 6        0.096491
# 665964   harry potter and the halfblood prince harry po...        0.091954
# 1021193  harry potter und der halbblutprinz harry potter 6        0.086191
# 920824                          blood work terry mccaleb 1        0.075389
# 923113       los juegos del hambre los juegos del hambre 1        0.074671
#
#                score
# 847638   1679.424998
# 694489   1034.821043
# 961156     77.172898
# 1050789    68.874100
# 836827     63.407037
# ...              ...
# 683683      0.394737
# 665964      0.390805
# 1021193     0.349836
# 920824      0.328972
# 923113      0.310633
#
# [228 rows x 10 columns]

# %%
def make_clickable(val):
    return '<a target="_blank" href="{}">Goodreads</a>'.format(val)

def show_image(val):
    return '<img src="{}" width=50></img>'.format(val)

# %%
top_recs.style.format({'url': make_clickable, 'cover_image': show_image})
# Out:
# <style type="text/css">
# </style>
# <table id="T_7f741">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f741_level0_col0" class="col_heading level0 col0" >book_id</th>
#       <th id="T_7f741_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_7f741_level0_col2" class="col_heading level0 col2" >mean</th>
#       <th id="T_7f741_level0_col3" class="col_heading level0 col3" >title</th>
#       <th id="T_7f741_level0_col4" class="col_heading level0 col4" >ratings</th>
#       <th id="T_7f741_level0_col5" class="col_heading level0 col5" >url</th>
#       <th id="T_7f741_level0_col6" class="col_heading level0 col6" >cover_image</th>
#       <th id="T_7f741_level0_col7" class="col_heading level0 col7" >mod_title</th>
#       <th id="T_7f741_level0_col8" class="col_heading level0 col8" >adjusted_count</th>
#       <th id="T_7f741_level0_col9" class="col_heading level0 col9" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f741_level0_row0" class="row_heading level0 row0" >847638</th>
#       <td id="T_7f741_row0_col0" class="data row0 col0" >5</td>
#       <td id="T_7f741_row0_col1" class="data row0 col1" >28048</td>
#       <td id="T_7f741_row0_col2" class="data row0 col2" >4.005419</td>
#       <td id="T_7f741_row0_col3" class="data row0 col3" >Harry Potter and the Prisoner of Azkaban (Harry Potter, #3)</td>
#       <td id="T_7f741_row0_col4" class="data row0 col4" >1876252</td>
#       <td id="T_7f741_row0_col5" class="data row0 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/5.Harry_Potter_and_the_Prisoner_of_Azkaban">Goodreads</a></td>
#       <td id="T_7f741_row0_col6" class="data row0 col6" ><img src="https://images.gr-assets.com/books/1499277281m/5.jpg" width=50></img></td>
#       <td id="T_7f741_row0_col7" class="data row0 col7" >harry potter and the prisoner of azkaban harry potter 3</td>
#       <td id="T_7f741_row0_col8" class="data row0 col8" >419.288189</td>
#       <td id="T_7f741_row0_col9" class="data row0 col9" >1679.424998</td>
#     </tr>
#     <tr>
#       <th id="T_7f741_level0_row1" class="row_heading level0 row1" >694489</th>
#       <td id="T_7f741_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_7f741_row1_col1" class="data row1 col1" >34576</td>
#       <td id="T_7f741_row1_col2" class="data row1 col2" >4.125000</td>
#       <td id="T_7f741_row1_col3" class="data row1 col3" >Harry Potter and the Sorcerer's Stone (Harry Potter, #1)</td>
#       <td id="T_7f741_row1_col4" class="data row1 col4" >4765497</td>
#       <td id="T_7f741_row1_col5" class="data row1 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/3.Harry_Potter_and_the_Sorcerer_s_Stone">Goodreads</a></td>
#       <td id="T_7f741_row1_col6" class="data row1 col6" ><img src="https://images.gr-assets.com/books/1474154022m/3.jpg" width=50></img></td>
#       <td id="T_7f741_row1_col7" class="data row1 col7" >harry potter and the sorcerers stone harry potter 1</td>
#       <td id="T_7f741_row1_col8" class="data row1 col8" >250.865707</td>
#       <td id="T_7f741_row1_col9" class="data row1 col9" >1034.821043</td>
#     </tr>
#     <tr>
#       <th id="T_7f741_level0_row2" class="row_heading level0 row2" >961156</th>
#       <td id="T_7f741_row2_col0" class="data row2 col0" >72193</td>
#       <td id="T_7f741_row2_col1" class="data row2 col1" >776</td>
#       <td id="T_7f741_row2_col2" class="data row2 col2" >4.051546</td>
#       <td id="T_7f741_row2_col3" class="data row2 col3" >Harry Potter and the Philosopher's Stone (Harry Potter, #1)</td>
#       <td id="T_7f741_row2_col4" class="data row2 col4" >31614</td>
#       <td id="T_7f741_row2_col5" class="data row2 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/72193.Harry_Potter_and_the_Philosopher_s_Stone">Goodreads</a></td>
#       <td id="T_7f741_row2_col6" class="data row2 col6" ><img src="https://images.gr-assets.com/books/1327190600m/72193.jpg" width=50></img></td>
#       <td id="T_7f741_row2_col7" class="data row2 col7" >harry potter and the philosophers stone harry potter 1</td>
#       <td id="T_7f741_row2_col8" class="data row2 col8" >19.047764</td>
#       <td id="T_7f741_row2_col9" class="data row2 col9" >77.172898</td>
#     </tr>
#     <tr>
#       <th id="T_7f741_level0_row3" class="row_heading level0 row3" >1050789</th>
#       <td id="T_7f741_row3_col0" class="data row3 col0" >90072</td>
#       <td id="T_7f741_row3_col1" class="data row3 col1" >1228</td>
#       <td id="T_7f741_row3_col2" class="data row3 col2" >4.182410</td>
#       <td id="T_7f741_row3_col3" class="data row3 col3" >Dr. Seuss's Green Eggs and Ham: For Soprano, Boy Soprano, and Orchestra</td>
#       <td id="T_7f741_row3_col4" class="data row3 col4" >91573</td>
#       <td id="T_7f741_row3_col5" class="data row3 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/90072.Dr_Seuss_s_Green_Eggs_and_Ham">Goodreads</a></td>
#       <td id="T_7f741_row3_col6" class="data row3 col6" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_7f741_row3_col7" class="data row3 col7" >dr seusss green eggs and ham for soprano boy soprano and orchestra</td>
#       <td id="T_7f741_row3_col8" class="data row3 col8" >16.467561</td>
#       <td id="T_7f741_row3_col9" class="data row3 col9" >68.874100</td>
#     </tr>
#     <tr>
#       <th id="T_7f741_level0_row4" class="row_heading level0 row4" >836827</th>
#       <td id="T_7f741_row4_col0" class="data row4 col0" >464164</td>
#       <td id="T_7f741_row4_col1" class="data row4 col1" >596</td>
#       <td id="T_7f741_row4_col2" class="data row4 col2" >4.068792</td>
#       <td id="T_7f741_row4_col3" class="data row4 col3" >Harry Potter and the Prisoner of Azkaban (Harry Potter, #3)</td>
#       <td id="T_7f741_row4_col4" class="data row4 col4" >22794</td>
#       <td id="T_7f741_row4_col5" class="data row4 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/464164.Harry_Potter_and_the_Prisoner_of_Azkaban">Goodreads</a></td>
#       <td id="T_7f741_row4_col6" class="data row4 col6" ><img src="https://images.gr-assets.com/books/1310384602m/464164.jpg" width=50></img></td>
#       <td id="T_7f741_row4_col7" class="data row4 col7" >harry potter and the prisoner of azkaban harry potter 3</td>
#       <td id="T_7f741_row4_col8" class="data row4 col8" >15.583750</td>
#       <td id="T_7f741_row4_col9" class="data row4 col9" >63.407037</td>
#     </tr>
#     <tr>
#       <th id="T_7f741_level0_row5" class="row_heading level0 row5" >1092065</th>
#       <td id="T_7f741_row5_col0" class="data row5 col0" >99298</td>
#       <td id="T_7f741_row5_col1" class="data row5 col1" >731</td>
#       <td id="T_7f741_row5_col2" class="data row5 col2" >4.179207</td>
#       <td id="T_7f741_row5_col3" class="data row5 col3" >The Harry Potter Collection 1-4 (Harry Potter, #1-4)</td>
#       <td id="T_7f741_row5_col4" class="data row5 col4" >44587</td>
#       <td id="T_7f741_row5_col5" class="data row5 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/99298.The_Harry_Potter_Collection_1_4">Goodreads</a></td>
#       <td id="T_7f741_row5_col6" class="data row5 col6" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_7f741_row5_col7" class="data row5 col7" >the harry potter collection 14 harry potter 14</td>
#       <td id="T_7f741_row5_col8" class="data row5 col8" >11.984682</td>
#       <td id="T_7f741_row5_col9" class="data row5 col9" >50.086460</td>
#     </tr>
#     <tr>
#       <th id="T_7f741_level0_row6" class="row_heading level0 row6" >1009618</th>
#       <td id="T_7f741_row6_col0" class="data row6 col0" >818056</td>
#       <td id="T_7f741_row6_col1" class="data row6 col1" >371</td>
#       <td id="T_7f741_row6_col2" class="data row6 col2" >4.061995</td>
#       <td id="T_7f741_row6_col3" class="data row6 col3" >Harry Potter and the Deathly Hallows (Harry Potter, #7)</td>
#       <td id="T_7f741_row6_col4" class="data row6 col4" >13938</td>
